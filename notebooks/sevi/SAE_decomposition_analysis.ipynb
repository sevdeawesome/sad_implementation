# %%
"""
Decompose steering direction into SAE features.

Find which SAE features (from llama_scope) are most aligned with
the self/other MMS steering direction at layer 21.
"""
import json
import torch
import numpy as np
from sae_lens import SAE

# %%
TOP_K = 20
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")

for version in ["V1", "V3"]:
    for layer in range(1, 25):
        print(f"Processing layer {layer} for version {version}")
        DIRECTION_PATH = f"/home/snfiel01/projects/sad_implementation/directions/llama3.1_8b_base_instruct_directions/{version}/mms_balanced_shared.json"
        output_path = f"outputs/{version}/sae_decomposition_layer{layer}.json"

        # Load SAE for layer 21 residual stream
        print(f"\nLoading SAE for layer {layer} residual stream...")

        print("Loading steering direction...")
        with open(DIRECTION_PATH) as f:
            data = json.load(f)

        direction = torch.tensor(data["shared_directions"][str(layer)], device=DEVICE)

        print(f"Direction shape: {direction.shape}, norm: {direction.norm().item():.4f}")

        # Load SAE for layer residual stream
        print(f"\nLoading SAE for layer {layer} residual stream...")

        sae, cfg_dict, sparsity = SAE.from_pretrained(
            release="llama_scope_lxr_8x",  # r = residual stream
            sae_id=f"l{layer}r_8x",        # layer 21 residual
            device=DEVICE
        )

                
        print(f"SAE config: {cfg_dict.get('d_sae', 'unknown')} features")

        # Get decoder weights (features -> residual stream)
        # Shape: (n_features, d_model)
        W_dec = sae.W_dec.detach()
        print(f"Decoder shape: {W_dec.shape}")

        # Normalize decoder directions
        W_dec_normalized = W_dec / W_dec.norm(dim=1, keepdim=True)

        # Compute cosine similarity between each SAE feature and steering direction
        # direction: (d_model,), W_dec_normalized: (n_features, d_model)
        cosine_sims = W_dec_normalized @ direction

        # Compute stats
        cos_min = cosine_sims.min().item()
        cos_max = cosine_sims.max().item()
        cos_mean = cosine_sims.mean().item()
        cos_std = cosine_sims.std().item()

        print(f"\nCosine similarity stats:")
        print(f"  Min: {cos_min:.4f}")
        print(f"  Max: {cos_max:.4f}")
        print(f"  Mean: {cos_mean:.4f}")
        print(f"  Std: {cos_std:.4f}")

        # Get top K most aligned features (positive alignment = same direction as self)
        top_positive_indices = torch.topk(cosine_sims, TOP_K).indices
        top_positive_values = cosine_sims[top_positive_indices]

        # Get top K most anti-aligned features (negative = opposite direction)
        top_negative_indices = torch.topk(-cosine_sims, TOP_K).indices
        top_negative_values = cosine_sims[top_negative_indices]

        print(f"\n{'='*60}")
        print(f"TOP {TOP_K} FEATURES ALIGNED WITH SELF-DIRECTION (Layer {layer})")
        print(f"{'='*60}")
        print(f"{'Rank':<6}{'Feature ID':<12}{'Cosine Sim':<12}{'Neuronpedia URL'}")
        print("-" * 60)
        for i, (idx, sim) in enumerate(zip(top_positive_indices, top_positive_values)):
            idx_val = idx.item()
            sim_val = sim.item()
            url = f"https://www.neuronpedia.org/llama3.1-8b/{layer}-llamascope-res-32k/{idx_val}"
            print(f"{i+1:<6}{idx_val:<12}{sim_val:<12.4f}{url}")

        print(f"\n{'='*60}")
        print(f"TOP {TOP_K} FEATURES ALIGNED WITH OTHER-DIRECTION (layer {layer})")
        print(f"(Negative alignment = opposite to self)")
        print(f"{'='*60}")
        print(f"{'Rank':<6}{'Feature ID':<12}{'Cosine Sim':<12}{'Neuronpedia URL'}")
        print("-" * 60)
        for i, (idx, sim) in enumerate(zip(top_negative_indices, top_negative_values)):
            idx_val = idx.item()
            sim_val = sim.item()
            url = f"https://www.neuronpedia.org/llama3.1-8b/{layer}-llamascope-res-32k/{idx_val}"
            print(f"{i+1:<6}{idx_val:<12}{sim_val:<12.4f}{url}")

        results = {
            "layer": layer,
            "direction_source": DIRECTION_PATH,
            "sae_release": "llama_scope_lxr_8x",
            "cosine_sim_stats": {
                "min": cos_min,
                "max": cos_max,
                "mean": cos_mean,
                "std": cos_std
            },
            "top_self_aligned": [
                {
                    "feature_id": idx.item(),
                    "cosine_sim": sim.item(),
                    "url": f"https://www.neuronpedia.org/llama3.1-8b/{layer}-llamascope-res-32k/{idx.item()}"
                }
                for idx, sim in zip(top_positive_indices, top_positive_values)
            ],
            "top_other_aligned": [
                {
                    "feature_id": idx.item(),
                    "cosine_sim": sim.item(),
                    "url": f"https://www.neuronpedia.org/llama3.1-8b/{layer}-llamascope-res-32k/{idx.item()}"
                }
                for idx, sim in zip(top_negative_indices, top_negative_values)
            ],
        }

        with open(output_path, "w") as f:
            json.dump(results, f, indent=2)
        print(f"\nResults saved to {output_path}")
# Out:
# Using device: cpu
# Processing layer 1 for version V1
#
# Loading SAE for layer 1 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 1 residual stream...
# /tmp/ipykernel_3849894/1512906786.py:25: DeprecationWarning: Unpacking SAE objects is deprecated. SAE.from_pretrained() now returns only the SAE object. Use SAE.from_pretrained_with_cfg_and_sparsity() to get the config dict and sparsity as well.
#   sae, cfg_dict, sparsity = SAE.from_pretrained(
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.2728
#   Max: 0.2614
#   Mean: 0.0024
#   Std: 0.0162
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 1)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     16858       0.2614      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/16858
# 2     27791       0.2129      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/27791
# 3     24736       0.1926      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/24736
# 4     13320       0.1785      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/13320
# 5     14476       0.1718      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/14476
# 6     7191        0.1567      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/7191
# 7     11674       0.1552      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/11674
# 8     10256       0.1531      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/10256
# 9     623         0.1434      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/623
# 10    7804        0.1297      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/7804
# 11    24325       0.1296      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/24325
# 12    5147        0.1236      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/5147
# 13    21197       0.1167      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/21197
# 14    5855        0.1135      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/5855
# 15    2406        0.1118      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/2406
# 16    11942       0.1112      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/11942
# 17    32285       0.1080      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/32285
# 18    2851        0.0986      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/2851
# 19    14776       0.0981      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/14776
# 20    24551       0.0979      https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/24551
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 1)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     20161       -0.2728     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/20161
# 2     31163       -0.2588     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/31163
# 3     32665       -0.2373     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/32665
# 4     10239       -0.2117     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/10239
# 5     27793       -0.2000     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/27793
# 6     17697       -0.1570     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/17697
# 7     26304       -0.1466     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/26304
# 8     31772       -0.1398     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/31772
# 9     8902        -0.1371     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/8902
# 10    26922       -0.1366     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/26922
# 11    4975        -0.1100     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/4975
# 12    3329        -0.1098     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/3329
# 13    21389       -0.1093     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/21389
# 14    12417       -0.1068     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/12417
# 15    4853        -0.1058     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/4853
# 16    19661       -0.1056     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/19661
# 17    21393       -0.1054     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/21393
# 18    3611        -0.0954     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/3611
# 19    17950       -0.0907     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/17950
# 20    7324        -0.0902     https://www.neuronpedia.org/llama3.1-8b/1-llamascope-res-32k/7324
#
# Results saved to outputs/V1/sae_decomposition_layer1.json
# Processing layer 2 for version V1
#
# Loading SAE for layer 2 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 2 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.2038
#   Max: 0.2328
#   Mean: 0.0012
#   Std: 0.0165
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 2)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     16329       0.2328      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/16329
# 2     6282        0.1458      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/6282
# 3     25244       0.1420      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/25244
# 4     20475       0.1415      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/20475
# 5     1057        0.1366      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/1057
# 6     15230       0.1359      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/15230
# 7     9126        0.1288      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/9126
# 8     32639       0.1210      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/32639
# 9     368         0.1189      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/368
# 10    9378        0.1080      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/9378
# 11    8411        0.1045      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/8411
# 12    11956       0.0976      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/11956
# 13    25384       0.0954      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/25384
# 14    6782        0.0950      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/6782
# 15    14272       0.0938      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/14272
# 16    20955       0.0899      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/20955
# 17    9365        0.0890      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/9365
# 18    4652        0.0885      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/4652
# 19    7737        0.0879      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/7737
# 20    2486        0.0872      https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/2486
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 2)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     22400       -0.2038     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/22400
# 2     17288       -0.1794     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/17288
# 3     20146       -0.1527     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/20146
# 4     18109       -0.1524     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/18109
# 5     9855        -0.1512     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/9855
# 6     2882        -0.1473     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/2882
# 7     12082       -0.1334     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/12082
# 8     14694       -0.1253     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/14694
# 9     1954        -0.1245     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/1954
# 10    26759       -0.1241     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/26759
# 11    24319       -0.1233     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/24319
# 12    3785        -0.1231     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/3785
# 13    30729       -0.1228     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/30729
# 14    553         -0.1223     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/553
# 15    17232       -0.1188     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/17232
# 16    26130       -0.1106     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/26130
# 17    14281       -0.1098     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/14281
# 18    1374        -0.1087     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/1374
# 19    3188        -0.1017     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/3188
# 20    11500       -0.1012     https://www.neuronpedia.org/llama3.1-8b/2-llamascope-res-32k/11500
#
# Results saved to outputs/V1/sae_decomposition_layer2.json
# Processing layer 3 for version V1
#
# Loading SAE for layer 3 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 3 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1494
#   Max: 0.1306
#   Mean: 0.0009
#   Std: 0.0166
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 3)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     3096        0.1306      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/3096
# 2     28550       0.1101      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/28550
# 3     26829       0.1044      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/26829
# 4     19227       0.1034      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/19227
# 5     28488       0.0991      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/28488
# 6     21306       0.0929      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/21306
# 7     19264       0.0904      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/19264
# 8     29875       0.0855      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/29875
# 9     15304       0.0854      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/15304
# 10    7638        0.0847      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/7638
# 11    27852       0.0812      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/27852
# 12    11065       0.0795      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/11065
# 13    32739       0.0786      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/32739
# 14    23859       0.0764      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/23859
# 15    8928        0.0749      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/8928
# 16    7767        0.0735      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/7767
# 17    28779       0.0704      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/28779
# 18    6733        0.0697      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/6733
# 19    24612       0.0691      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/24612
# 20    682         0.0669      https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/682
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 3)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     24118       -0.1494     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/24118
# 2     15693       -0.1468     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/15693
# 3     32573       -0.1406     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/32573
# 4     8869        -0.1247     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/8869
# 5     3738        -0.1213     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/3738
# 6     7819        -0.1190     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/7819
# 7     13033       -0.1180     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/13033
# 8     27016       -0.1116     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/27016
# 9     29653       -0.1113     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/29653
# 10    20171       -0.1090     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/20171
# 11    24280       -0.1051     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/24280
# 12    20955       -0.1032     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/20955
# 13    19629       -0.1001     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/19629
# 14    11273       -0.0999     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/11273
# 15    26897       -0.0989     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/26897
# 16    3733        -0.0969     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/3733
# 17    21292       -0.0961     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/21292
# 18    30055       -0.0958     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/30055
# 19    23869       -0.0949     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/23869
# 20    21367       -0.0945     https://www.neuronpedia.org/llama3.1-8b/3-llamascope-res-32k/21367
#
# Results saved to outputs/V1/sae_decomposition_layer3.json
# Processing layer 4 for version V1
#
# Loading SAE for layer 4 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 4 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1358
#   Max: 0.1223
#   Mean: -0.0002
#   Std: 0.0171
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 4)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     24422       0.1223      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/24422
# 2     21309       0.1169      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/21309
# 3     17252       0.1022      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/17252
# 4     2927        0.0992      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/2927
# 5     2887        0.0964      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/2887
# 6     21344       0.0941      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/21344
# 7     5202        0.0928      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/5202
# 8     11322       0.0923      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/11322
# 9     17107       0.0915      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/17107
# 10    2485        0.0909      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/2485
# 11    27979       0.0898      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/27979
# 12    25289       0.0872      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/25289
# 13    11745       0.0849      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/11745
# 14    26972       0.0841      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/26972
# 15    12822       0.0828      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/12822
# 16    14627       0.0803      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/14627
# 17    9236        0.0792      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/9236
# 18    5387        0.0790      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/5387
# 19    19390       0.0769      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/19390
# 20    13998       0.0742      https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/13998
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 4)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     29961       -0.1358     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/29961
# 2     8872        -0.1290     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/8872
# 3     18643       -0.1211     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/18643
# 4     12229       -0.1130     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/12229
# 5     12568       -0.1115     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/12568
# 6     26401       -0.1094     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/26401
# 7     16191       -0.1081     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/16191
# 8     11846       -0.0998     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/11846
# 9     26524       -0.0997     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/26524
# 10    1039        -0.0975     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/1039
# 11    31746       -0.0931     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/31746
# 12    4381        -0.0924     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/4381
# 13    7446        -0.0891     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/7446
# 14    10962       -0.0889     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/10962
# 15    27472       -0.0887     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/27472
# 16    8293        -0.0879     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/8293
# 17    24513       -0.0859     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/24513
# 18    15118       -0.0843     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/15118
# 19    11576       -0.0842     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/11576
# 20    9266        -0.0834     https://www.neuronpedia.org/llama3.1-8b/4-llamascope-res-32k/9266
#
# Results saved to outputs/V1/sae_decomposition_layer4.json
# Processing layer 5 for version V1
#
# Loading SAE for layer 5 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 5 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1188
#   Max: 0.1493
#   Mean: 0.0001
#   Std: 0.0178
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 5)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     21818       0.1493      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/21818
# 2     19534       0.1355      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/19534
# 3     3636        0.1245      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/3636
# 4     9662        0.1143      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/9662
# 5     27363       0.1110      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/27363
# 6     8664        0.1109      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/8664
# 7     9117        0.1106      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/9117
# 8     31795       0.1099      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/31795
# 9     20932       0.1065      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/20932
# 10    18442       0.0958      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/18442
# 11    22895       0.0903      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/22895
# 12    20035       0.0868      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/20035
# 13    11157       0.0847      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/11157
# 14    30709       0.0845      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/30709
# 15    6656        0.0843      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/6656
# 16    13854       0.0835      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/13854
# 17    505         0.0834      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/505
# 18    24839       0.0811      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/24839
# 19    31107       0.0808      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/31107
# 20    30487       0.0800      https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/30487
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 5)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     14235       -0.1188     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/14235
# 2     24125       -0.1027     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/24125
# 3     21768       -0.0997     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/21768
# 4     22209       -0.0958     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/22209
# 5     22691       -0.0944     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/22691
# 6     1313        -0.0900     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/1313
# 7     13268       -0.0895     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/13268
# 8     20651       -0.0865     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/20651
# 9     13652       -0.0791     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/13652
# 10    17385       -0.0768     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/17385
# 11    29060       -0.0765     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/29060
# 12    13139       -0.0761     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/13139
# 13    12875       -0.0748     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/12875
# 14    6836        -0.0745     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/6836
# 15    24367       -0.0733     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/24367
# 16    16467       -0.0731     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/16467
# 17    20047       -0.0724     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/20047
# 18    14994       -0.0722     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/14994
# 19    7534        -0.0718     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/7534
# 20    7769        -0.0696     https://www.neuronpedia.org/llama3.1-8b/5-llamascope-res-32k/7769
#
# Results saved to outputs/V1/sae_decomposition_layer5.json
# Processing layer 6 for version V1
#
# Loading SAE for layer 6 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 6 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1079
#   Max: 0.1651
#   Mean: 0.0022
#   Std: 0.0184
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 6)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     18022       0.1651      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/18022
# 2     17000       0.1510      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/17000
# 3     19202       0.1173      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/19202
# 4     14388       0.1173      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/14388
# 5     22994       0.1157      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/22994
# 6     14198       0.1150      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/14198
# 7     19620       0.1135      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/19620
# 8     21556       0.1127      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/21556
# 9     19017       0.1079      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/19017
# 10    12303       0.1058      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/12303
# 11    6839        0.1045      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/6839
# 12    29626       0.1013      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/29626
# 13    27515       0.0978      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/27515
# 14    17771       0.0961      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/17771
# 15    9793        0.0960      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/9793
# 16    9840        0.0931      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/9840
# 17    3559        0.0919      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/3559
# 18    9924        0.0909      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/9924
# 19    21425       0.0900      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/21425
# 20    12778       0.0888      https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/12778
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 6)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     19951       -0.1079     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/19951
# 2     9409        -0.1000     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/9409
# 3     10379       -0.0876     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/10379
# 4     25671       -0.0839     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/25671
# 5     19515       -0.0808     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/19515
# 6     29440       -0.0772     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/29440
# 7     15570       -0.0745     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/15570
# 8     29201       -0.0696     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/29201
# 9     22040       -0.0695     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/22040
# 10    24910       -0.0693     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/24910
# 11    10927       -0.0691     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/10927
# 12    7733        -0.0686     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/7733
# 13    20067       -0.0680     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/20067
# 14    23539       -0.0669     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/23539
# 15    13124       -0.0656     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/13124
# 16    8228        -0.0653     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/8228
# 17    11390       -0.0651     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/11390
# 18    22138       -0.0650     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/22138
# 19    7358        -0.0649     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/7358
# 20    5970        -0.0633     https://www.neuronpedia.org/llama3.1-8b/6-llamascope-res-32k/5970
#
# Results saved to outputs/V1/sae_decomposition_layer6.json
# Processing layer 7 for version V1
#
# Loading SAE for layer 7 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 7 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1587
#   Max: 0.1355
#   Mean: 0.0019
#   Std: 0.0188
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 7)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     10664       0.1355      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/10664
# 2     27514       0.1244      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/27514
# 3     10826       0.1155      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/10826
# 4     4468        0.1131      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/4468
# 5     24232       0.1078      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/24232
# 6     8568        0.1054      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/8568
# 7     30681       0.1052      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/30681
# 8     19094       0.1038      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/19094
# 9     6417        0.0959      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/6417
# 10    26941       0.0958      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/26941
# 11    14967       0.0951      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/14967
# 12    4456        0.0927      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/4456
# 13    11766       0.0924      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/11766
# 14    331         0.0912      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/331
# 15    3435        0.0888      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/3435
# 16    9091        0.0885      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/9091
# 17    20615       0.0846      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/20615
# 18    2909        0.0845      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/2909
# 19    15454       0.0844      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/15454
# 20    13182       0.0843      https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/13182
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 7)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     26261       -0.1587     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/26261
# 2     2843        -0.1087     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/2843
# 3     11763       -0.1084     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/11763
# 4     17528       -0.1047     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/17528
# 5     26429       -0.1035     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/26429
# 6     1448        -0.0990     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/1448
# 7     3093        -0.0964     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/3093
# 8     891         -0.0891     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/891
# 9     11281       -0.0827     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/11281
# 10    4291        -0.0825     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/4291
# 11    959         -0.0824     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/959
# 12    18019       -0.0816     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/18019
# 13    1929        -0.0787     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/1929
# 14    12209       -0.0766     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/12209
# 15    23942       -0.0749     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/23942
# 16    29615       -0.0748     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/29615
# 17    9394        -0.0742     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/9394
# 18    4819        -0.0729     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/4819
# 19    8241        -0.0728     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/8241
# 20    49          -0.0724     https://www.neuronpedia.org/llama3.1-8b/7-llamascope-res-32k/49
#
# Results saved to outputs/V1/sae_decomposition_layer7.json
# Processing layer 8 for version V1
#
# Loading SAE for layer 8 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 8 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1258
#   Max: 0.1569
#   Mean: 0.0041
#   Std: 0.0189
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 8)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     31944       0.1569      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/31944
# 2     24803       0.1542      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/24803
# 3     27379       0.1435      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/27379
# 4     2083        0.1337      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/2083
# 5     19894       0.1256      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/19894
# 6     9266        0.1148      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/9266
# 7     28780       0.1078      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/28780
# 8     9962        0.1072      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/9962
# 9     19847       0.1045      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/19847
# 10    5709        0.1041      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/5709
# 11    3439        0.0981      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/3439
# 12    11930       0.0977      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/11930
# 13    1347        0.0967      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/1347
# 14    26879       0.0948      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/26879
# 15    9394        0.0944      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/9394
# 16    3090        0.0935      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/3090
# 17    27064       0.0928      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/27064
# 18    15868       0.0916      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/15868
# 19    15117       0.0916      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/15117
# 20    9653        0.0899      https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/9653
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 8)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     25544       -0.1258     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/25544
# 2     24315       -0.1015     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/24315
# 3     24591       -0.0967     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/24591
# 4     26627       -0.0959     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/26627
# 5     15581       -0.0910     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/15581
# 6     6811        -0.0811     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/6811
# 7     31726       -0.0809     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/31726
# 8     8243        -0.0803     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/8243
# 9     27932       -0.0799     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/27932
# 10    30490       -0.0795     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/30490
# 11    30632       -0.0754     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/30632
# 12    13818       -0.0751     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/13818
# 13    1999        -0.0736     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/1999
# 14    25150       -0.0723     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/25150
# 15    23014       -0.0713     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/23014
# 16    11273       -0.0701     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/11273
# 17    17066       -0.0699     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/17066
# 18    10130       -0.0687     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/10130
# 19    27215       -0.0676     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/27215
# 20    25769       -0.0676     https://www.neuronpedia.org/llama3.1-8b/8-llamascope-res-32k/25769
#
# Results saved to outputs/V1/sae_decomposition_layer8.json
# Processing layer 9 for version V1
#
# Loading SAE for layer 9 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 9 residual stream...
# hyperparams.json: 0.00B [00:00, ?B/s]
# Llama3_1-8B-Base-L9R-8x/checkpoints/fina(…):   0%|          | 0.00/537M [00:00<?, ?B/s]
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1016
#   Max: 0.2620
#   Mean: 0.0026
#   Std: 0.0185
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 9)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     2529        0.2620      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/2529
# 2     31971       0.1512      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/31971
# 3     16789       0.1304      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/16789
# 4     3255        0.1177      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/3255
# 5     10615       0.1076      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/10615
# 6     18868       0.0956      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/18868
# 7     25664       0.0952      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/25664
# 8     3301        0.0936      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/3301
# 9     22844       0.0936      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/22844
# 10    29590       0.0907      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/29590
# 11    21089       0.0888      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/21089
# 12    22181       0.0873      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/22181
# 13    12072       0.0847      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/12072
# 14    2782        0.0843      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/2782
# 15    11661       0.0824      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/11661
# 16    6043        0.0818      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/6043
# 17    13098       0.0810      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/13098
# 18    21921       0.0807      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/21921
# 19    17801       0.0778      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/17801
# 20    17105       0.0777      https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/17105
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 9)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     16557       -0.1016     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/16557
# 2     27681       -0.0981     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/27681
# 3     17620       -0.0974     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/17620
# 4     27232       -0.0915     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/27232
# 5     21577       -0.0898     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/21577
# 6     18403       -0.0874     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/18403
# 7     14499       -0.0871     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/14499
# 8     24820       -0.0869     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/24820
# 9     20931       -0.0865     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/20931
# 10    3384        -0.0860     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/3384
# 11    1126        -0.0838     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/1126
# 12    13060       -0.0824     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/13060
# 13    4763        -0.0816     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/4763
# 14    5110        -0.0814     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/5110
# 15    23088       -0.0805     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/23088
# 16    19616       -0.0782     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/19616
# 17    30817       -0.0731     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/30817
# 18    7514        -0.0713     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/7514
# 19    18303       -0.0707     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/18303
# 20    4579        -0.0706     https://www.neuronpedia.org/llama3.1-8b/9-llamascope-res-32k/4579
#
# Results saved to outputs/V1/sae_decomposition_layer9.json
# Processing layer 10 for version V1
#
# Loading SAE for layer 10 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 10 residual stream...
# hyperparams.json: 0.00B [00:00, ?B/s]
# Llama3_1-8B-Base-L10R-8x/checkpoints/fin(…):   0%|          | 0.00/537M [00:00<?, ?B/s]
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1856
#   Max: 0.1960
#   Mean: 0.0052
#   Std: 0.0188
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 10)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     31907       0.1960      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/31907
# 2     10750       0.1879      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/10750
# 3     8925        0.1245      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/8925
# 4     18806       0.1240      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/18806
# 5     8784        0.1212      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/8784
# 6     3564        0.1186      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/3564
# 7     14433       0.1184      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/14433
# 8     1447        0.1151      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/1447
# 9     28879       0.1082      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/28879
# 10    2963        0.1081      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/2963
# 11    7602        0.1046      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/7602
# 12    30478       0.1018      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/30478
# 13    9210        0.0992      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/9210
# 14    3142        0.0986      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/3142
# 15    2776        0.0982      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/2776
# 16    26290       0.0965      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/26290
# 17    22027       0.0960      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/22027
# 18    24069       0.0923      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/24069
# 19    9015        0.0909      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/9015
# 20    13755       0.0895      https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/13755
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 10)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     17875       -0.1856     https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/17875
# 2     2301        -0.0955     https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/2301
# 3     31273       -0.0944     https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/31273
# 4     30407       -0.0863     https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/30407
# 5     5609        -0.0811     https://www.neuronpedia.org/llama3.1-8b/10-llamascope-res-32k/5609
# ...
# 10    15596       -0.1014     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/15596
# 11    26486       -0.1013     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/26486
# 12    7234        -0.0990     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/7234
# 13    7050        -0.0968     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/7050
# 14    9583        -0.0956     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/9583
# 15    26524       -0.0931     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/26524
# 16    32064       -0.0919     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/32064
# 17    8139        -0.0900     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/8139
# 18    7495        -0.0882     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/7495
# 19    2235        -0.0878     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/2235
# 20    6700        -0.0868     https://www.neuronpedia.org/llama3.1-8b/21-llamascope-res-32k/6700
#
# Results saved to outputs/V3/sae_decomposition_layer21.json
# Processing layer 22 for version V3
#
# Loading SAE for layer 22 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 22 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1490
#   Max: 0.2321
#   Mean: 0.0016
#   Std: 0.0180
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 22)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     10022       0.2321      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/10022
# 2     29772       0.1309      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/29772
# 3     26141       0.0974      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/26141
# 4     14117       0.0969      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/14117
# 5     2584        0.0952      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/2584
# 6     23002       0.0936      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/23002
# 7     24626       0.0915      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/24626
# 8     20509       0.0876      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/20509
# 9     9062        0.0848      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/9062
# 10    12039       0.0825      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/12039
# 11    25393       0.0822      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/25393
# 12    5064        0.0797      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/5064
# 13    6100        0.0783      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/6100
# 14    13157       0.0782      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/13157
# 15    15370       0.0772      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/15370
# 16    32079       0.0763      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/32079
# 17    28150       0.0751      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/28150
# 18    11266       0.0744      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/11266
# 19    27363       0.0743      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/27363
# 20    6062        0.0739      https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/6062
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 22)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     9104        -0.1490     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/9104
# 2     4779        -0.1401     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/4779
# 3     10042       -0.1352     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/10042
# 4     20562       -0.1317     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/20562
# 5     758         -0.1281     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/758
# 6     13910       -0.1197     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/13910
# 7     18613       -0.1183     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/18613
# 8     10362       -0.1177     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/10362
# 9     5148        -0.1094     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/5148
# 10    29836       -0.1092     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/29836
# 11    24735       -0.1085     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/24735
# 12    8622        -0.1066     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/8622
# 13    28489       -0.1049     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/28489
# 14    8766        -0.1009     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/8766
# 15    6803        -0.0975     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/6803
# 16    3636        -0.0957     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/3636
# 17    22441       -0.0934     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/22441
# 18    30040       -0.0931     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/30040
# 19    555         -0.0924     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/555
# 20    2036        -0.0924     https://www.neuronpedia.org/llama3.1-8b/22-llamascope-res-32k/2036
#
# Results saved to outputs/V3/sae_decomposition_layer22.json
# Processing layer 23 for version V3
#
# Loading SAE for layer 23 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 23 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.2072
#   Max: 0.2193
#   Mean: 0.0018
#   Std: 0.0179
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 23)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     30309       0.2193      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/30309
# 2     1096        0.1215      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/1096
# 3     2279        0.1100      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/2279
# 4     32119       0.0977      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/32119
# 5     16218       0.0954      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/16218
# 6     6649        0.0925      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/6649
# 7     23308       0.0910      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/23308
# 8     26806       0.0902      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/26806
# 9     27240       0.0898      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/27240
# 10    32484       0.0897      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/32484
# 11    15293       0.0863      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/15293
# 12    15041       0.0837      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/15041
# 13    22523       0.0822      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/22523
# 14    10137       0.0799      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/10137
# 15    17115       0.0791      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/17115
# 16    3084        0.0745      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/3084
# 17    31203       0.0742      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/31203
# 18    31586       0.0740      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/31586
# 19    14983       0.0731      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/14983
# 20    17187       0.0731      https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/17187
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 23)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     507         -0.2072     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/507
# 2     25592       -0.1722     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/25592
# 3     16944       -0.1668     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/16944
# 4     15227       -0.1234     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/15227
# 5     4205        -0.1209     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/4205
# 6     2864        -0.1118     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/2864
# 7     19733       -0.1104     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/19733
# 8     5247        -0.1052     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/5247
# 9     1798        -0.1044     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/1798
# 10    3239        -0.1035     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/3239
# 11    32506       -0.1028     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/32506
# 12    3314        -0.1017     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/3314
# 13    26058       -0.1004     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/26058
# 14    8941        -0.0981     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/8941
# 15    12366       -0.0962     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/12366
# 16    9573        -0.0937     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/9573
# 17    594         -0.0930     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/594
# 18    23281       -0.0927     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/23281
# 19    20395       -0.0918     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/20395
# 20    17634       -0.0910     https://www.neuronpedia.org/llama3.1-8b/23-llamascope-res-32k/17634
#
# Results saved to outputs/V3/sae_decomposition_layer23.json
# Processing layer 24 for version V3
#
# Loading SAE for layer 24 residual stream...
# Loading steering direction...
# Direction shape: torch.Size([4096]), norm: 1.0000
#
# Loading SAE for layer 24 residual stream...
# SAE config: 32768 features
# Decoder shape: torch.Size([32768, 4096])
#
# Cosine similarity stats:
#   Min: -0.1795
#   Max: 0.2471
#   Mean: 0.0017
#   Std: 0.0175
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH SELF-DIRECTION (Layer 24)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     18793       0.2471      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/18793
# 2     26075       0.1691      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/26075
# 3     10956       0.1060      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/10956
# 4     462         0.0958      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/462
# 5     21168       0.0911      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/21168
# 6     12550       0.0901      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/12550
# 7     17991       0.0890      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/17991
# 8     17870       0.0880      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/17870
# 9     24493       0.0846      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/24493
# 10    30817       0.0821      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/30817
# 11    55          0.0816      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/55
# 12    28404       0.0809      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/28404
# 13    12021       0.0756      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/12021
# 14    23075       0.0752      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/23075
# 15    3558        0.0741      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/3558
# 16    17474       0.0726      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/17474
# 17    23917       0.0725      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/23917
# 18    27250       0.0721      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/27250
# 19    2373        0.0720      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/2373
# 20    15446       0.0712      https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/15446
#
# ============================================================
# TOP 20 FEATURES ALIGNED WITH OTHER-DIRECTION (layer 24)
# (Negative alignment = opposite to self)
# ============================================================
# Rank  Feature ID  Cosine Sim  Neuronpedia URL
# ------------------------------------------------------------
# 1     7237        -0.1795     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/7237
# 2     2903        -0.1736     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/2903
# 3     14746       -0.1524     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/14746
# 4     19873       -0.1232     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/19873
# 5     24210       -0.1155     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/24210
# 6     23848       -0.1091     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/23848
# 7     32206       -0.1058     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/32206
# 8     22860       -0.1049     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/22860
# 9     17030       -0.1042     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/17030
# 10    1283        -0.1032     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/1283
# 11    27473       -0.1008     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/27473
# 12    29419       -0.1005     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/29419
# 13    23483       -0.1000     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/23483
# 14    27677       -0.0958     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/27677
# 15    29894       -0.0934     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/29894
# 16    11539       -0.0920     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/11539
# 17    21215       -0.0913     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/21215
# 18    14804       -0.0903     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/14804
# 19    1152        -0.0876     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/1152
# 20    1478        -0.0873     https://www.neuronpedia.org/llama3.1-8b/24-llamascope-res-32k/1478
#
# Results saved to outputs/V3/sae_decomposition_layer24.json
